# %% [markdown]
# # Data Import

# %%
import pandas as pd

# %%
#Method 1: Specify Full Path To File

# %%
#Windows
# stats = pd.read_csv('C:\\Users\\Kiril\\Desktop\\')
# Mac
stats = pd.read_csv('/Users/lionhunter/PycharmProjects/Python For Data Science/Data Frames/P4-Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
#Method 2: Change Working Directory

# %%
import os

# %%
print(os.getcwd())
# Out:
# /Users/lionhunter/PycharmProjects/Python For Data Science/Data Frames

# %%
os.chdir('/Users/lionhunter/Desktop')

# %%
print(os.getcwd())
# Out:
# /Users/lionhunter/Desktop

# %%
stats2 = pd.read_csv('P4-Demographic-Data.csv') #Error!
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-952c3d563061> in <module>
# ----> 1 stats2 = pd.read_csv('P4-Demographic-Data.csv') #Error!
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'P4-Demographic-Data.csv'

# %%
os.chdir('/Users/lionhunter/PycharmProjects/Python For Data Science/Data Frames')

# %%
print(os.getcwd())
# Out:
# /Users/lionhunter/PycharmProjects/Python For Data Science/Data Frames

# %%
stats2 = pd.read_csv('P4-Demographic-Data.csv')

# %%
stats2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Exploring Your Data

# %%
# 1. Full DataFrame

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
# 2. Number Of Rows

# %%
len(stats) #195 rows imported
# Out:
# 195

# %%
# 3. See columns

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
# 4. Number of Columns

# %%
len(stats.columns)
# Out:
# 5

# %%
# 5. Top Rows

# %%
stats.head(10) #Remember the brackets, in brackets we can give numbers
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
# 6. Bottom Rows

# %%
stats.tail(10)
# Out:
#               Country Name Country Code  Birth rate  Internet users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# 7. Information on the Columns

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# 8. Get Stats on the Columns

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# ---

# %% [markdown]
# # Renaming Columns of a DataFrame

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['CountryName', 'CountryCode',
                 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %% [markdown]
# # Subsetting DataFrames in Pandas

# %%
# Three Parts, Buckle Up!
# -Rows
# -Columns
# -Combine The Two

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# # Rows

# %%
stats[160:180]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 160              Suriname         SUR     18.455        37.4000
# 161       Slovak Republic         SVK     10.100        77.8826
# 162              Slovenia         SVN     10.200        72.6756
# 163                Sweden         SWE     11.800        94.7836
# 164             Swaziland         SWZ     30.093        24.7000
# 165            Seychelles         SYC     18.600        50.4000
# 166  Syrian Arab Republic         SYR     24.043        26.2000
# 167                  Chad         TCD     45.745         2.3000
# 168                  Togo         TGO     36.080         4.5000
# 169              Thailand         THA     11.041        28.9400
# 170            Tajikistan         TJK     30.792        16.0000
# 171          Turkmenistan         TKM     21.322         9.6000
# 172           Timor-Leste         TLS     35.755         1.1000
# 173                 Tonga         TON     25.409        35.0000
# 174   Trinidad and Tobago         TTO     14.590        63.8000
# 175               Tunisia         TUN     19.800        43.8000
# 176                Turkey         TUR     16.836        46.2500
# 177              Tanzania         TZA     39.518         4.4000
# 178                Uganda         UGA     43.474        16.2000
# 179               Ukraine         UKR     11.100        41.0000
#
#              IncomeGroup
# 160  Upper middle income
# 161          High income
# 162          High income
# 163          High income
# 164  Lower middle income
# 165          High income
# 166  Lower middle income
# 167           Low income
# 168           Low income
# 169  Upper middle income
# 170  Lower middle income
# 171  Upper middle income
# 172  Lower middle income
# 173  Upper middle income
# 174          High income
# 175  Upper middle income
# 176  Upper middle income
# 177           Low income
# 178           Low income
# 179  Lower middle income

# %%
# Quick Exercise (Refresher)
# Reverse the dataframe

# %%
stats[180:160:-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 180               Uruguay         URY     14.374        57.6900
# 179               Ukraine         UKR     11.100        41.0000
# 178                Uganda         UGA     43.474        16.2000
# 177              Tanzania         TZA     39.518         4.4000
# 176                Turkey         TUR     16.836        46.2500
# 175               Tunisia         TUN     19.800        43.8000
# 174   Trinidad and Tobago         TTO     14.590        63.8000
# 173                 Tonga         TON     25.409        35.0000
# 172           Timor-Leste         TLS     35.755         1.1000
# 171          Turkmenistan         TKM     21.322         9.6000
# 170            Tajikistan         TJK     30.792        16.0000
# 169              Thailand         THA     11.041        28.9400
# 168                  Togo         TGO     36.080         4.5000
# 167                  Chad         TCD     45.745         2.3000
# 166  Syrian Arab Republic         SYR     24.043        26.2000
# 165            Seychelles         SYC     18.600        50.4000
# 164             Swaziland         SWZ     30.093        24.7000
# 163                Sweden         SWE     11.800        94.7836
# 162              Slovenia         SVN     10.200        72.6756
# 161       Slovak Republic         SVK     10.100        77.8826
#
#              IncomeGroup
# 180          High income
# 179  Lower middle income
# 178           Low income
# 177           Low income
# 176  Upper middle income
# 175  Upper middle income
# 174          High income
# 173  Upper middle income
# 172  Lower middle income
# 171  Upper middle income
# 170  Lower middle income
# 169  Upper middle income
# 168           Low income
# 167           Low income
# 166  Lower middle income
# 165          High income
# 164  Lower middle income
# 163          High income
# 162          High income
# 161          High income

# %%
# Quick Exercise (Refresher)
# Get only every 20th

# %%
stats[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %% [markdown]
# # Columns

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
stats['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
['CountryName', 'BirthRate']
# Out:
# ['CountryName', 'BirthRate']

# %%
stats[['CountryName', 'BirthRate']].head()
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
stats[['BirthRate', 'CountryName']].head()
# Out:
#    BirthRate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
# Quick Access - Requires the name to be one word

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
stats.BirthRate.head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %% [markdown]
# # Combining the Two

# %%
stats[4:8][['CountryName', 'BirthRate']]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats[['CountryName', 'BirthRate']][4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %% [markdown]
# ---

# %% [markdown]
# # Basic Operations With DataFrames

# %%
# Already Spoke About Subsetting. Refresh:

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[['CountryCode', 'BirthRate', 'InternetUsers']][160:180]
# Out:
#     CountryCode  BirthRate  InternetUsers
# 160         SUR     18.455        37.4000
# 161         SVK     10.100        77.8826
# 162         SVN     10.200        72.6756
# 163         SWE     11.800        94.7836
# 164         SWZ     30.093        24.7000
# 165         SYC     18.600        50.4000
# 166         SYR     24.043        26.2000
# 167         TCD     45.745         2.3000
# 168         TGO     36.080         4.5000
# 169         THA     11.041        28.9400
# 170         TJK     30.792        16.0000
# 171         TKM     21.322         9.6000
# 172         TLS     35.755         1.1000
# 173         TON     25.409        35.0000
# 174         TTO     14.590        63.8000
# 175         TUN     19.800        43.8000
# 176         TUR     16.836        46.2500
# 177         TZA     39.518         4.4000
# 178         UGA     43.474        16.2000
# 179         UKR     11.100        41.0000

# %% [markdown]
# # Mathematical Operations

# %%
result = stats.BirthRate * stats.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
# Add columns

# %%
stats['MyCalc'] = stats.BirthRate * stats.InternetUsers

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
# Removing a Column

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats.drop('MyCalc', axis = 1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats = stats.drop('MyCalc', axis = 1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %% [markdown]
# # Filtering Data Frames

# %%
# Filtering is about Rows

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.InternetUsers < 10
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
InternetUserFilter = stats.InternetUsers < 5

# %%
InternetUserFilter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[InternetUserFilter]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 13                      Benin         BEN     36.440            4.9
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 117                   Myanmar         MMR     18.119            1.6
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# 156                   Somalia         SOM     43.891            1.5
# 167                      Chad         TCD     45.745            2.3
# 168                      Togo         TGO     36.080            4.5
# 172               Timor-Leste         TLS     35.755            1.1
# 177                  Tanzania         TZA     39.518            4.4
# 192          Congo, Dem. Rep.         COD     42.394            2.2
#
#              IncomeGroup
# 11            Low income
# 13            Low income
# 29            Low income
# 52            Low income
# 55            Low income
# 64            Low income
# 66            Low income
# 99            Low income
# 111           Low income
# 115           Low income
# 117  Lower middle income
# 127           Low income
# 154           Low income
# 156           Low income
# 167           Low income
# 168           Low income
# 172  Lower middle income
# 177           Low income
# 192           Low income

# %%
# Awesome! Let's use this in practice now:

# %%
BirthRateFilter = stats.BirthRate > 40

# %%
stats[BirthRateFilter]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# 128  Lower middle income
# 156           Low income
# 167           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
stats[stats.BirthRate > 38]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985          19.10
# 11            Burundi         BDI     44.151           1.30
# 14       Burkina Faso         BFA     40.551           9.10
# 65        Gambia, The         GMB     42.525          14.00
# 115              Mali         MLI     44.138           3.50
# 120        Mozambique         MOZ     39.705           5.40
# 123            Malawi         MWI     39.459           5.05
# 127             Niger         NER     49.661           1.70
# 128           Nigeria         NGA     40.045          38.00
# 151           Senegal         SEN     38.533          13.10
# 156           Somalia         SOM     43.891           1.50
# 167              Chad         TCD     45.745           2.30
# 177          Tanzania         TZA     39.518           4.40
# 178            Uganda         UGA     43.474          16.20
# 192  Congo, Dem. Rep.         COD     42.394           2.20
# 193            Zambia         ZMB     40.471          15.40
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 120           Low income
# 123           Low income
# 127           Low income
# 128  Lower middle income
# 151  Lower middle income
# 156           Low income
# 167           Low income
# 177           Low income
# 178           Low income
# 192           Low income
# 193  Lower middle income

# %%
# Even More Interesting:

# %%
stats[stats.BirthRate > 40 and stats.InternetUsers < 2] #Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-2721b13e7bce> in <module>
# ----> 1 stats[stats.BirthRate > 40 and stats.InternetUsers < 2] #Error
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1439     @final
#    1440     def __nonzero__(self):
# -> 1441         raise ValueError(
#    1442             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1443             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats[InternetUserFilter and BirthRateFilter] # Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-ac46e6fbe1eb> in <module>
# ----> 1 stats[InternetUserFilter and BirthRateFilter] # Error
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1439     @final
#    1440     def __nonzero__(self):
# -> 1441         raise ValueError(
#    1442             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1443             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats[InternetUserFilter & BirthRateFilter]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
stats[(stats.BirthRate > 40) & (stats.InternetUsers < 5)]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 115              Mali         MLI     44.138            3.5  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
#Another One

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats.IncomeGroup == "High income"]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
# How To Get the Unique Categories

# %%
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats[stats.IncomeGroup == "Upper middle income"]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 2                            Angola         AGO     45.985      19.100000
# 3                           Albania         ALB     12.877      57.200000
# 10                       Azerbaijan         AZE     18.300      58.700000
# 16                         Bulgaria         BGR      9.200      53.061500
# 19           Bosnia and Herzegovina         BIH      9.062      57.790000
# 20                          Belarus         BLR     12.500      54.170000
# 21                           Belize         BLZ     23.092      33.600000
# 24                           Brazil         BRA     14.931      51.040000
# 28                         Botswana         BWA     25.267      15.000000
# 33                            China         CHN     12.100      45.800000
# 37                         Colombia         COL     16.076      51.700000
# 40                       Costa Rica         CRI     15.022      45.960000
# 41                             Cuba         CUB     10.400      27.930000
# 48               Dominican Republic         DOM     21.198      45.900000
# 49                          Algeria         DZA     24.738      16.500000
# 50                          Ecuador         ECU     21.070      40.353684
# 57                             Fiji         FJI     20.463      37.100000
# 60                            Gabon         GAB     30.555       9.200000
# 69                          Grenada         GRD     19.334      35.000000
# 82               Iran, Islamic Rep.         IRN     17.900      29.950000
# 83                             Iraq         IRQ     31.093       9.200000
# 87                          Jamaica         JAM     13.540      37.100000
# 88                           Jordan         JOR     27.046      41.000000
# 90                       Kazakhstan         KAZ     22.730      54.000000
# 98                          Lebanon         LBN     13.426      70.500000
# 100                           Libya         LBY     21.425      16.500000
# 101                       St. Lucia         LCA     15.430      46.200000
# 112                        Maldives         MDV     21.447      44.100000
# 113                          Mexico         MEX     19.104      43.460000
# 114                  Macedonia, FYR         MKD     11.222      65.240000
# 118                      Montenegro         MNE     11.616      60.310000
# 119                        Mongolia         MNG     24.275      20.000000
# 122                       Mauritius         MUS     10.900      39.000000
# 124                        Malaysia         MYS     16.805      66.970000
# 125                         Namibia         NAM     29.937      13.900000
# 136                          Panama         PAN     19.680      44.030000
# 137                            Peru         PER     20.198      39.200000
# 143                        Paraguay         PRY     21.588      36.900000
# 146                         Romania         ROU      8.800      49.764500
# 157                          Serbia         SRB      9.200      51.500000
# 160                        Suriname         SUR     18.455      37.400000
# 169                        Thailand         THA     11.041      28.940000
# 171                    Turkmenistan         TKM     21.322       9.600000
# 173                           Tonga         TON     25.409      35.000000
# 175                         Tunisia         TUN     19.800      43.800000
# 176                          Turkey         TUR     16.836      46.250000
# 183  St. Vincent and the Grenadines         VCT     16.306      52.000000
# 191                    South Africa         ZAF     20.850      46.500000
#
#              IncomeGroup
# 2    Upper middle income
# 3    Upper middle income
# 10   Upper middle income
# 16   Upper middle income
# 19   Upper middle income
# 20   Upper middle income
# 21   Upper middle income
# 24   Upper middle income
# 28   Upper middle income
# 33   Upper middle income
# 37   Upper middle income
# 40   Upper middle income
# 41   Upper middle income
# 48   Upper middle income
# 49   Upper middle income
# 50   Upper middle income
# 57   Upper middle income
# 60   Upper middle income
# 69   Upper middle income
# 82   Upper middle income
# 83   Upper middle income
# 87   Upper middle income
# 88   Upper middle income
# 90   Upper middle income
# 98   Upper middle income
# 100  Upper middle income
# 101  Upper middle income
# 112  Upper middle income
# 113  Upper middle income
# 114  Upper middle income
# 118  Upper middle income
# 119  Upper middle income
# 122  Upper middle income
# 124  Upper middle income
# 125  Upper middle income
# 136  Upper middle income
# 137  Upper middle income
# 143  Upper middle income
# 146  Upper middle income
# 157  Upper middle income
# 160  Upper middle income
# 169  Upper middle income
# 171  Upper middle income
# 173  Upper middle income
# 175  Upper middle income
# 176  Upper middle income
# 183  Upper middle income
# 191  Upper middle income

# %%
# Quick Exercise
# Find About Everything About Turkey

# %%
stats[stats.CountryName == "Turkey"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 176      Turkey         TUR     16.836          46.25  Upper middle income

# %% [markdown]
# ---

# %% [markdown]
# # Accessing Individual Elements

# %%
stats[2,2] #Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 2)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-507e82b4ed26> in <module>
# ----> 1 stats[2,2] #Error
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: (2, 2)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# # .at # For labels. Important: Even Integers are Treated as Labels
#
# # .iat # For Integer Location

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,0]
# Out:
# 'Aruba'

# %%
stats.at[2,'BirthRate']
# Out:
# 45.985

# %%
# Why we need .at?

# %%
sub10 = stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# 110      Moldova         MDA     12.141      45.000000  Lower middle income
# 120   Mozambique         MOZ     39.705       5.400000           Low income
# 130  Netherlands         NLD     10.200      93.956400          High income
# 140       Poland         POL      9.600      62.849200          High income
# 150        Sudan         SDN     33.477      22.700000  Lower middle income
# 160     Suriname         SUR     18.455      37.400000  Upper middle income
# 170   Tajikistan         TJK     30.792      16.000000  Lower middle income
# 180      Uruguay         URY     14.374      57.690000          High income
# 190  Yemen, Rep.         YEM     32.947      20.000000  Lower middle income

# %%
sub10.iat[10,0] # It looks for 10th Index
# Out:
# 'Libya'

# %%
sub10.at[10, 'CountryName'] # It looks for the '10' Label
# Out:
# 'Azerbaijan'

# %% [markdown]
# ---

# %% [markdown]
# # Introduction To Seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize']= 8,4

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Distribution

# %%
vis1 = sns.distplot(stats["InternetUsers"])

# %%
vis1 = sns.distplot(stats["InternetUsers"], bins = 30)

# %%
# Boxplots:

# %%
vis2 = sns.boxplot(data=stats, x = "IncomeGroup", y = "BirthRate")

# %%
# Seaborn Gallery Just Look At It

# %% [markdown]
# ---

# %%
vis3 = sns.lmplot(data=stats, x = "InternetUsers", y = "BirthRate")

# %%
vis3 = sns.lmplot(data=stats, x = "InternetUsers", y = "BirthRate", fit_reg=False)

# %%
vis3 = sns.lmplot(data=stats, x = "InternetUsers", y = "BirthRate",
                  fit_reg=False, hue='IncomeGroup')

# %%
vis3 = sns.lmplot(data=stats, x = "InternetUsers", y = "BirthRate",
                  fit_reg=False, hue='IncomeGroup', size=7)

# %%
vis3 = sns.lmplot(data=stats, x = "InternetUsers", y = "BirthRate",
                  fit_reg=False, hue='IncomeGroup', size=7, aspect=2)

# %% [markdown]
# ---

# %% [markdown]
# # Keyword Arguments in Python (Advanced Tutorial)

# %%
#Change The Marker Size

# %%
vis3 = sns.lmplot(data=stats, x = "InternetUsers", y = "BirthRate",
                  fit_reg=False, hue='IncomeGroup', size=8,      \
                 scatter_kws={"s":200})
